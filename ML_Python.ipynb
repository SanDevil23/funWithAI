# %% [markdown]
# # Python Machine Learning

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

data = pd.read_csv("student-mat.csv", sep=";")
# print(data.head())

data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
# print(data.head())

predict = "G3"

m = data.drop([predict], axis=1)

x = np.array(m)
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)

acc= linear.score(x_test, y_test)

print("Accuracy (in %) = ",acc*100)          # final accuracy in percentage


with open("studentModel.pickle", "wb") as f:
    pickle.dump(linear, f)

pickle_in = open("studentModel.pickle", "rb")
linear = pickle.load(pickle_in)
 
# print('Coeffecient : \n', linear.coef_)
# print('Intercept : \n', linear.intecept_)

predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# Accuracy (in %) =  93.95479067420565
# 13.150579568427206 [10 13  1  0 12] 12
# 13.011481128467215 [14 13  2  0  2] 13
# 15.142479100272649 [15 15  2  0  2] 16
# 13.943156647135321 [15 14  3  0  2] 15
# 18.39354545454789 [19 18  3  0  0] 19
# 10.692090292860081 [11 11  2  0  4] 11
# -1.222623657116664 [7 0 3 0 0] 0
# 8.251338913108704 [10  9  3  0  2] 9
# 7.070868892826663 [8 8 2 0 0] 9
# 15.099815358276164 [14 15  2  0  4] 15
# 19.073453908252013 [18 18  1  0  8] 18
# 10.360511888708798 [12 10  2  0 14] 11
# -0.5787482635638126 [10  0  2  0  0] 0
# -2.013543179441056 [5 0 1 3 0] 0
# 12.865752006662005 [13 13  2  0  2] 13
# 4.957608816836975 [5 6 2 0 6] 6
# 5.725260049364351 [7 7 4 0 4] 6
# 9.304932244440822 [ 9 10  2  0  2] 9
# 12.495039692384056 [14 13  4  0  0] 14
# 15.28820822207786 [16 15  2  0  2] 15
# 8.910408621021675 [ 7 10  2  0  0] 11
# 14.978454814131922 [16 15  3  0  0] 15
# 9.924154450666943 [ 8  9  1  1 38] 8
# 12.219913304264338 [10  9  2  0 75] 9
# 8.1665686976355 [8 9 2 0 2] 8
# 8.399441481221658 [ 7 10  3  1  0] 10
# 3.9198811058345067 [ 6  5  1  3 16] 5
# 11.520700431719463 [12 12  3  0  2] 11
# 8.944611254209384 [10 10  3  2  8] 10
# 9.262268502444336 [ 8 10  2  0  4] 9
# 4.89720717902474 [6 6 2 0 2] 6
# 13.763632731241497 [12 14  3  0  7] 14
# 12.023763731230474 [14 12  2  1  8] 12
# 10.69264756137985 [11 11  1  0  0] 12
# 11.934076487993899 [12 12  1  0  2] 14
# 12.616957505048068 [12 13  2  0  0] 14
# 18.70329886249383 [19 18  2  0  2] 18
# 9.553726746054757 [10 10  2  0  4] 11
# 12.969374654990498 [13 13  1  0  0] 12
# -0.7244773853690237 [9 0 2 0 0] 0

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

data = pd.read_csv("student-mat.csv", sep=";")
# print(data.head())

data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
# print(data.head())

predict = "G3"

m = data.drop([predict], axis=1)

x = np.array(m)
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)

# linear = linear_model.LinearRegression()

# linear.fit(x_train, y_train)

# acc= linear.score(x_test, y_test)

# print("Accuracy (in %) = ",acc*100)          # final accuracy in percentage


# with open("studentModel.pickle", "wb") as f:
#     pickle.dump(linear, f)

pickle_in = open("studentModel.pickle", "rb")
linear = pickle.load(pickle_in)
 
# print('Coeffecient : \n', linear.coef_)
# print('Intercept : \n', linear.intecept_)

predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# 7.504398139747128 [7 9 4 0 0] 0
# 8.561092321054645 [10  9  2  0  4] 9
# 16.38279348984716 [16 16  4  0 12] 16
# 14.261359213078288 [11 12  2  0 54] 11
# 8.354961561437197 [10  9  2  0  0] 9
# 8.1665686976355 [8 9 2 0 2] 10
# 8.270191345963992 [8 9 1 0 0] 8
# 3.861909012028139 [5 5 2 0 4] 6
# -0.6635184790370172 [8 0 1 0 0] 0
# 13.113989239756169 [14 13  3  0  8] 14
# 4.4253739493513855 [ 6  5  1  1 14] 5
# 12.277067421508683 [14 12  1  0  3] 12
# 10.19450128963221 [ 9 11  2  0  0] 12
# 13.901050173658604 [14 14  2  0  0] 14
# 12.960356277661948 [15 13  3  2 14] 13
# 17.17041169226936 [16 17  2  0  0] 17
# 10.051315749282626 [12 10  2  0  8] 11
# 14.766250641189021 [11 15  1  0  2] 15
# 12.023763731230474 [14 12  2  1  8] 12
# 15.700469741312755 [16 15  2  0 10] 15
# 11.685281986379962 [11 12  1  0  0] 10
# 11.248094620964329 [ 8 12  1  0  0] 12
# 11.520700431719463 [12 12  3  0  2] 11
# 5.786776224216128 [6 7 2 0 0] 0
# 8.934219930162874 [10 10  4  0  0] 10
# 6.074147367436959 [ 7  6  1  0 18] 6
# 12.345780738709022 [12 12  2  0 14] 12
# 19.073453908252013 [18 18  1  0  8] 18
# 7.611121638051021 [11  8  2  0  2] 8
# 15.142479100272649 [15 15  2  0  2] 16
# 12.841383429001036 [10 13  1  0  6] 13
# 13.424299916221882 [14 13  1  0  6] 13
# 12.328600111413046 [14 12  1  0  4] 11
# 11.976740229990385 [13 12  1  0  0] 12
# 10.22365171481146 [10 10  2  0 17] 10
# 16.90276475780014 [17 17  4  0  0] 18
# 12.574293763051582 [11 13  2  0  2] 14
# 9.119082962094751 [11  9  2  0 12] 9
# 12.828562560948658 [12 13  1  1  6] 14
# 11.993920857286364 [11 12  2  0 10] 13

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

data = pd.read_csv("student-mat.csv", sep=";")
# print(data.head())

data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
# print(data.head())

predict = "G3"

m = data.drop([predict], axis=1)

x = np.array(m)
y = np.array(data[predict])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)

best = 0

for _ in range(30):
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)
    
    linear = linear_model.LinearRegression()
    
    linear.fit(x_train, y_train)
    
    acc= linear.score(x_test, y_test)
    
    print("Accuracy (in %) = ",acc*100)          # final accuracy in percentage

    if acc> best:
        best = acc
        with open("studentModel.pickle", "wb") as f:
            pickle.dump(linear, f)


print("Best = ", best*100, "%")
pickle_in = open("studentModel.pickle", "rb")
linear = pickle.load(pickle_in)
 
# print('Coeffecient : \n', linear.coef_)
# print('Intercept : \n', linear.intecept_)

predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# Accuracy (in %) =  84.77349390527303
# Accuracy (in %) =  89.4312295562886
# Accuracy (in %) =  88.15073786054188
# Accuracy (in %) =  82.72451941289964
# Accuracy (in %) =  74.12794324641196
# Accuracy (in %) =  80.55085081979814
# Accuracy (in %) =  85.90663765468267
# Accuracy (in %) =  79.44965303177504
# Accuracy (in %) =  82.13208215024663
# Accuracy (in %) =  73.32369480951722
# Accuracy (in %) =  78.9065257637572
# Accuracy (in %) =  75.35934274395002
# Accuracy (in %) =  86.66970527117805
# Accuracy (in %) =  84.06016868823885
# Accuracy (in %) =  76.71862364164956
# Accuracy (in %) =  88.94942608991276
# Accuracy (in %) =  84.53694166283748
# Accuracy (in %) =  77.4797719808983
# Accuracy (in %) =  74.60686197402794
# Accuracy (in %) =  89.05248532699605
# Accuracy (in %) =  92.53373127339806
# Accuracy (in %) =  86.93932268413461
# Accuracy (in %) =  91.94438799561617
# Accuracy (in %) =  82.2449437228391
# Accuracy (in %) =  86.54372290332797
# Accuracy (in %) =  89.77149690576233
# Accuracy (in %) =  82.48324046965992
# Accuracy (in %) =  78.19534244515194
# Accuracy (in %) =  77.75881551470303
# Accuracy (in %) =  83.12600523143816
# Best =  92.53373127339806 %
# 7.227495612249848 [8 8 2 0 2] 8
# 8.955284917632719 [ 7 10  2  0  0] 11
# 11.322864447534657 [10 12  3  0  4] 12
# 7.020721647418007 [8 8 3 0 2] 10
# 12.617886965690783 [13 13  3  0  0] 13
# 8.20659308558643 [8 9 2 0 2] 8
# 11.27560109461775 [ 8 12  1  0  0] 12
# 13.055066571812917 [14 13  2  0  2] 13
# 13.130124947623186 [14 13  2  0  4] 13
# 14.938203142675816 [14 15  2  0  0] 15
# 12.047106908158392 [12 12  1  0  4] 13
# 15.643317577993377 [16 15  1  0  5] 16
# 10.118569826241469 [12 10  2  1 18] 10
# 8.512057102686992 [9 9 2 0 6] 10
# 16.128578231996514 [15 16  3  0  7] 15
# 19.003892092678576 [18 18  1  0  8] 18
# 4.956692188034443 [7 6 1 1 0] 0
# 14.576081912363948 [13 15  3  0  0] 15
# 9.65775854366088 [10 10  2  1 14] 9
# 16.331915713100663 [18 16  3  0  0] 16
# 12.56646026633897 [14 13  4  0  0] 14
# -0.9178926519850493 [7 0 1 1 0] 0
# 10.089729656449327 [ 8 11  2  0  0] 11
# 11.129987994149497 [ 9 12  3  0  3] 11
# 16.38334241245248 [17 16  2  0  0] 17
# 7.312714438599308 [5 9 2 2 6] 7
# 7.0188077008358185 [9 8 2 1 0] 0
# 6.9970899709595535 [7 8 2 0 0] 0
# 19.367898185379126 [19 19  4  0  4] 20
# 15.09805405930812 [16 15  4  0  7] 17
# 8.385572027524912 [10  9  3  0  4] 9
# 7.581745519412824 [ 9  8  2  1 15] 8
# 10.348997488057567 [11 11  3  0  0] 10
# 5.414186903337727 [ 7  6  2  0 10] 6
# 10.625599314840182 [10 11  2  0  6] 11
# 12.215624822377887 [12 12  2  0 14] 12
# 13.479842119440377 [15 14  3  2  4] 15
# 9.317406147944586 [ 8 10  1  0  0] 11
# 18.186190093645614 [16 18  2  0  0] 18
# 9.467522899565122 [ 8 10  1  0  4] 10

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

data = pd.read_csv("student-mat.csv", sep=";")
# print(data.head())

data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
# print(data.head())

predict = "G3"

m = data.drop([predict], axis=1)

x = np.array(m)
y = np.array(data[predict])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)

'''
best = 0

for _ in range(30):
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.1)
    
    linear = linear_model.LinearRegression()
    
    linear.fit(x_train, y_train)
    
    acc= linear.score(x_test, y_test)
    
    print("Accuracy (in %) = ",acc*100)          # final accuracy in percentage

    if acc> best:
        best = acc
        with open("studentModel.pickle", "wb") as f:
            pickle.dump(linear, f)


print("Best = ", best*100, "%")
'''
pickle_in = open("studentModel.pickle", "rb")
linear = pickle.load(pickle_in)
 
# print('Coeffecient : \n', linear.coef_)
# print('Intercept : \n', linear.intecept_)

predictions = linear.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])


p = 'G1'
style.use("ggplot")
plt.scatter(data[p], data["G3"])
plt.xlabel(p)
plt.ylabel("Final Grade")
plt.show()
# Out:
# 15.09355040815584 [15 15  2  0  0] 15
# 9.783447944384667 [11 10  1  0  0] 10
# 6.337354026170214 [7 7 1 0 3] 8
# 7.562639514632455 [7 9 4 0 0] 0
# 11.63164503191252 [13 12  2  1  2] 12
# 15.76113565556827 [17 15  1  0  4] 16
# 9.228428240161836 [11  9  1  1 19] 10
# 14.24093800998134 [14 14  1  0  2] 14
# 9.180460045063521 [ 7 10  2  0  6] 10
# 16.236662144559638 [14 16  1  0  3] 16
# 10.142223523225725 [11 11  4  0  0] 11
# 4.347656079889706 [ 6  5  1  1 14] 5
# 8.338308674608005 [8 9 1 0 0] 8
# 9.52001676634152 [11 10  3  0  4] 11
# 10.362168136797036 [10 11  4  0 10] 11
# 19.90793119020489 [18 19  1  0  6] 19
# 13.130124947623186 [14 13  2  0  4] 13
# 12.052337422017883 [13 12  1  0  0] 12
# 3.449665191186983 [3 5 2 1 8] 5
# 5.306409359851632 [8 7 2 3 0] 0
# 11.985219181087594 [11 12  2  0 12] 11
# 12.325593597329691 [11 13  4  0  6] 14
# 10.442457026466794 [11 11  4  0  8] 10
# 14.081427398066406 [16 14  4  0  6] 15
# 9.52001676634152 [11 10  3  0  4] 10
# 14.264569686439796 [15 14  2  0  4] 14
# 6.136606249636162 [ 6  7  2  1 15] 8
# 10.089729656449327 [ 8 11  2  0  0] 11
# 17.85031932855579 [17 17  2  0 13] 17
# 9.467522899565122 [ 8 10  1  0  4] 10
# 14.576059891838144 [15 14  2  1 20] 13
# 12.589024775372838 [11 13  2  0  2] 14
# 9.23295391183992 [10 10  4  0  6] 11
# 12.669313665042598 [12 13  2  0  0] 13
# 18.445457925253855 [19 18  3  0  0] 19
# 8.93683265031445 [10 10  3  2  8] 10
# 15.323956049446137 [16 15  2  0  2] 15
# 8.310513651714643 [10  9  3  0  2] 8
# 14.881545929464506 [14 15  3  0  4] 16
# 10.698743744068262 [11 11  1  1  6] 10

# %% [markdown]
# # K-Nearest Neighbours (KNN)

# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

data = pd.read_csv('car.data')
print(data.head())

# transforming 
# non-numerical data 
# into numerical data using preprocessing

le = preprocessing.LabelEncoder()

buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

# print(buying)

predict="class"

X = list(zip(buying, maint, door, persons, lug_boot, safety)) 
Y = list(cls) 

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(
, 0, 0, 2), (2, 2, 1, 2, 2, 1), (1, 0, 0, 0, 0, 1), (2, 3, 3, 0, 1, 2), (1, 3, 2, 0, 1, 2), (0, 1, 2, 2, 0, 1), (3, 2, 0, 0, 0, 2), (3, 2, 1, 0, 1, 2), (1, 3, 0, 1, 2, 0), (0, 3, 0, 1, 1, 0), (0, 0, 0, 2, 1, 2), (3, 3, 3, 2, 2, 1), (1, 3, 3, 1, 0, 0), (2, 1, 2, 0, 0, 2), (1, 0, 1, 2, 0, 0), (1, 0, 2, 0, 0, 2), (2, 3, 2, 1, 0, 1), (1, 2, 3, 0, 0, 2), (0, 2, 1, 1, 1, 2), (0, 0, 1, 1, 1, 0), (0, 3, 1, 1, 0, 1), (1, 3, 3, 1, 0, 1), (2, 3, 3, 2, 0, 1), (1, 2, 1, 0, 2, 1), (2, 2, 3, 2, 1, 1), (3, 1, 0, 0, 1, 1), (1, 1, 1, 0, 2, 2), (2, 0, 0, 1, 0, 0), (3, 2, 3, 2, 1, 0), ...

# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

data = pd.read_csv('car.data')
print(data.head())

# transforming 
# non-numerical data 
# into numerical data using preprocessing

le = preprocessing.LabelEncoder()

buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

# print(buying)

predict="class"

X = list(zip(buying, maint, door, persons, lug_boot, safety)) 
Y = list(cls) 

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X,Y, test_size=0.1)

# print(x_train, y_test)

model = KNeighborsClassifier(n_neighbors = 9)
model.fit(x_train, y_train)
acc = model.score(x_test, y_test)
print(acc)

predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for x in range(len(x_test)):
    print("Predicted: ", names[predicted[x]], "|| Data: ", x_test[x], "|| Actual: ", names[y_test[x]])
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc
# 0.9595375722543352
# Predicted:  good || Data:  (1, 0, 2, 0, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 3, 1, 1, 1, 0) || Actual:  good
# Predicted:  good || Data:  (0, 3, 1, 2, 1, 0) || Actual:  good
# Predicted:  good || Data:  (0, 0, 3, 0, 2, 0) || Actual:  good
# Predicted:  vgood || Data:  (1, 2, 2, 2, 1, 0) || Actual:  vgood
# Predicted:  unacc || Data:  (2, 2, 2, 2, 2, 2) || Actual:  unacc
# Predicted:  vgood || Data:  (1, 0, 3, 2, 0, 0) || Actual:  vgood
# Predicted:  unacc || Data:  (2, 0, 2, 1, 0, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (1, 0, 3, 2, 2, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (3, 2, 3, 2, 0, 0) || Actual:  unacc
# Predicted:  good || Data:  (0, 3, 3, 1, 1, 0) || Actual:  good
# Predicted:  unacc || Data:  (1, 0, 1, 1, 1, 2) || Actual:  unacc
# Predicted:  good || Data:  (1, 3, 0, 1, 1, 2) || Actual:  good
# Predicted:  unacc || Data:  (2, 2, 0, 2, 1, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (0, 2, 1, 2, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (1, 3, 0, 0, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 3, 1, 0, 1, 2) || Actual:  good
# Predicted:  unacc || Data:  (3, 1, 3, 2, 1, 2) || Actual:  unacc
# Predicted:  good || Data:  (3, 3, 3, 2, 0, 0) || Actual:  good
# Predicted:  unacc || Data:  (2, 3, 2, 1, 0, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (3, 0, 3, 2, 0, 2) || Actual:  good
# Predicted:  good || Data:  (3, 0, 0, 0, 2, 0) || Actual:  good
# Predicted:  acc || Data:  (2, 1, 2, 2, 2, 0) || Actual:  acc
# Predicted:  unacc || Data:  (0, 2, 3, 2, 2, 0) || Actual:  unacc
# Predicted:  good || Data:  (0, 2, 3, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 2, 1, 0, 0, 1) || Actual:  good
# Predicted:  good || Data:  (3, 0, 2, 2, 0, 1) || Actual:  good
# Predicted:  good || Data:  (1, 2, 0, 1, 2, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (2, 2, 1, 1, 1, 2) || Actual:  unacc
# Predicted:  acc || Data:  (1, 2, 1, 2, 0, 2) || Actual:  acc
# Predicted:  good || Data:  (3, 1, 0, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (3, 3, 0, 2, 0, 0) || Actual:  good
# Predicted:  good || Data:  (1, 3, 3, 1, 1, 1) || Actual:  good
# Predicted:  unacc || Data:  (3, 1, 2, 1, 2, 0) || Actual:  unacc
# Predicted:  good || Data:  (2, 2, 2, 0, 0, 0) || Actual:  good
# Predicted:  good || Data:  (0, 1, 3, 0, 0, 2) || Actual:  good
# Predicted:  good || Data:  (2, 3, 3, 0, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 0, 1, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 0, 1, 0, 2, 1) || Actual:  good
# Predicted:  acc || Data:  (1, 1, 0, 1, 0, 2) || Actual:  acc
# Predicted:  good || Data:  (2, 0, 0, 2, 2, 2) || Actual:  good
# Predicted:  good || Data:  (3, 2, 0, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (1, 3, 2, 0, 2, 2) || Actual:  good
# Predicted:  good || Data:  (1, 1, 0, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 1, 1, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (3, 2, 0, 2, 2, 0) || Actual:  good
# Predicted:  good || Data:  (1, 3, 0, 1, 2, 0) || Actual:  unacc
# Predicted:  good || Data:  (2, 2, 1, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (3, 3, 2, 2, 1, 0) || Actual:  good
# Predicted:  good || Data:  (1, 3, 1, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (2, 2, 1, 0, 1, 2) || Actual:  good
# Predicted:  acc || Data:  (1, 1, 0, 2, 1, 0) || Actual:  acc
# Predicted:  good || Data:  (0, 0, 2, 0, 2, 0) || Actual:  good
# Predicted:  unacc || Data:  (0, 0, 3, 2, 2, 0) || Actual:  unacc
# Predicted:  unacc || Data:  (1, 3, 3, 1, 1, 2) || Actual:  unacc
# Predicted:  vgood || Data:  (2, 1, 2, 2, 0, 0) || Actual:  vgood
# Predicted:  good || Data:  (2, 0, 0, 0, 0, 0) || Actual:  good
# Predicted:  good || Data:  (1, 0, 1, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 2, 1, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (2, 1, 0, 2, 2, 0) || Actual:  good
# Predicted:  good || Data:  (3, 2, 3, 0, 2, 0) || Actual:  good
# Predicted:  good || Data:  (2, 3, 3, 1, 0, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (2, 2, 1, 1, 2, 0) || Actual:  unacc
# Predicted:  good || Data:  (0, 2, 1, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (1, 0, 3, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (3, 2, 0, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 0, 0, 1, 0, 0) || Actual:  unacc
# Predicted:  good || Data:  (3, 1, 0, 1, 2, 2) || Actual:  good
# Predicted:  good || Data:  (3, 2, 3, 0, 1, 0) || Actual:  good
# Predicted:  unacc || Data:  (2, 2, 2, 2, 0, 2) || Actual:  unacc
# Predicted:  good || Data:  (3, 3, 1, 1, 0, 2) || Actual:  good
# Predicted:  vgood || Data:  (2, 1, 3, 1, 0, 0) || Actual:  vgood
# Predicted:  good || Data:  (0, 2, 3, 1, 2, 1) || Actual:  good
# Predicted:  unacc || Data:  (0, 0, 0, 2, 1, 2) || Actual:  good
# Predicted:  unacc || Data:  (0, 2, 3, 2, 1, 2) || Actual:  unacc
# Predicted:  good || Data:  (2, 0, 0, 2, 1, 1) || Actual:  good
# Predicted:  unacc || Data:  (1, 0, 1, 1, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (1, 0, 3, 1, 1, 1) || Actual:  good
# Predicted:  unacc || Data:  (0, 1, 3, 2, 0, 0) || Actual:  unacc
# Predicted:  acc || Data:  (1, 2, 1, 1, 2, 0) || Actual:  acc
# Predicted:  good || Data:  (0, 3, 1, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (0, 1, 2, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 3, 1, 0, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 0, 2, 2, 0, 2) || Actual:  good
# Predicted:  unacc || Data:  (1, 3, 1, 2, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (2, 0, 3, 0, 2, 0) || Actual:  good
# Predicted:  good || Data:  (1, 1, 2, 0, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 2, 1, 1, 2, 1) || Actual:  good
# Predicted:  unacc || Data:  (0, 1, 1, 2, 1, 2) || Actual:  unacc
# Predicted:  good || Data:  (0, 3, 0, 2, 2, 0) || Actual:  good
# Predicted:  good || Data:  (1, 3, 3, 0, 1, 1) || Actual:  good
# Predicted:  vgood || Data:  (2, 1, 2, 1, 1, 0) || Actual:  vgood
# Predicted:  unacc || Data:  (0, 0, 2, 2, 1, 2) || Actual:  unacc
# Predicted:  good || Data:  (0, 3, 2, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (3, 3, 0, 1, 0, 1) || Actual:  good
# Predicted:  good || Data:  (1, 1, 3, 2, 2, 1) || Actual:  good
# Predicted:  unacc || Data:  (2, 1, 2, 1, 2, 2) || Actual:  unacc
# Predicted:  good || Data:  (1, 0, 1, 1, 0, 1) || Actual:  good
# Predicted:  good || Data:  (0, 3, 0, 2, 0, 0) || Actual:  good
# Predicted:  good || Data:  (2, 0, 0, 1, 2, 2) || Actual:  good
# Predicted:  unacc || Data:  (1, 1, 2, 2, 2, 2) || Actual:  unacc
# Predicted:  good || Data:  (0, 1, 0, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (3, 0, 0, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (3, 0, 0, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 0, 1, 2, 0, 1) || Actual:  good
# Predicted:  good || Data:  (3, 0, 0, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (2, 1, 0, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (3, 1, 1, 1, 2, 2) || Actual:  good
# Predicted:  unacc || Data:  (2, 3, 0, 1, 0, 0) || Actual:  unacc
# Predicted:  good || Data:  (3, 0, 0, 1, 0, 1) || Actual:  good
# Predicted:  unacc || Data:  (3, 1, 1, 2, 0, 0) || Actual:  unacc
# Predicted:  vgood || Data:  (1, 0, 2, 1, 0, 0) || Actual:  vgood
# Predicted:  acc || Data:  (1, 1, 1, 1, 1, 0) || Actual:  acc
# Predicted:  unacc || Data:  (0, 0, 0, 1, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (2, 0, 0, 1, 1, 2) || Actual:  good
# Predicted:  good || Data:  (3, 3, 1, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 2, 2, 0, 2, 2) || Actual:  good
# Predicted:  good || Data:  (0, 1, 2, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (0, 3, 2, 2, 0, 1) || Actual:  good
# Predicted:  good || Data:  (0, 1, 3, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (3, 2, 1, 0, 0, 1) || Actual:  good
# Predicted:  good || Data:  (1, 1, 3, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 3, 1, 1, 0, 1) || Actual:  good
# Predicted:  good || Data:  (3, 3, 3, 2, 1, 0) || Actual:  good
# Predicted:  good || Data:  (1, 2, 2, 2, 0, 1) || Actual:  good
# Predicted:  good || Data:  (3, 2, 0, 0, 0, 0) || Actual:  good
# Predicted:  good || Data:  (3, 1, 2, 0, 2, 2) || Actual:  good
# Predicted:  good || Data:  (3, 1, 1, 2, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 3, 3, 0, 0, 1) || Actual:  good
# Predicted:  good || Data:  (1, 0, 2, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (1, 1, 3, 1, 1, 1) || Actual:  good
# Predicted:  unacc || Data:  (1, 3, 2, 1, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (1, 1, 2, 0, 2, 0) || Actual:  good
# Predicted:  good || Data:  (2, 1, 1, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (0, 2, 1, 1, 0, 2) || Actual:  unacc
# Predicted:  vgood || Data:  (2, 1, 1, 2, 1, 0) || Actual:  vgood
# Predicted:  good || Data:  (0, 2, 2, 2, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 2, 2, 1, 0, 1) || Actual:  good
# Predicted:  good || Data:  (2, 1, 3, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (0, 0, 0, 2, 2, 0) || Actual:  good
# Predicted:  acc || Data:  (1, 1, 2, 2, 1, 2) || Actual:  acc
# Predicted:  good || Data:  (2, 1, 2, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (1, 2, 1, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (1, 2, 1, 1, 1, 1) || Actual:  good
# Predicted:  good || Data:  (2, 3, 1, 0, 0, 2) || Actual:  good
# Predicted:  good || Data:  (3, 1, 2, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (2, 1, 3, 0, 0, 2) || Actual:  good
# Predicted:  good || Data:  (1, 1, 3, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (2, 3, 2, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (1, 1, 0, 0, 1, 0) || Actual:  good
# Predicted:  good || Data:  (0, 0, 1, 2, 1, 1) || Actual:  good
# Predicted:  good || Data:  (2, 3, 2, 1, 0, 1) || Actual:  good
# Predicted:  unacc || Data:  (3, 2, 1, 2, 1, 0) || Actual:  unacc
# Predicted:  unacc || Data:  (2, 2, 0, 2, 1, 0) || Actual:  unacc
# Predicted:  good || Data:  (1, 3, 2, 1, 2, 2) || Actual:  good
# Predicted:  good || Data:  (2, 0, 1, 0, 1, 1) || Actual:  good
# Predicted:  unacc || Data:  (0, 1, 1, 1, 0, 2) || Actual:  unacc
# Predicted:  good || Data:  (0, 3, 3, 1, 2, 0) || Actual:  good
# Predicted:  good || Data:  (3, 2, 1, 0, 2, 0) || Actual:  good
# Predicted:  good || Data:  (2, 3, 3, 1, 0, 1) || Actual:  good
# Predicted:  unacc || Data:  (0, 1, 1, 2, 0, 0) || Actual:  unacc
# Predicted:  good || Data:  (3, 2, 2, 1, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 3, 3, 0, 2, 1) || Actual:  good
# Predicted:  good || Data:  (0, 1, 2, 0, 0, 1) || Actual:  good
# Predicted:  unacc || Data:  (2, 2, 3, 1, 0, 2) || Actual:  unacc
# Predicted:  unacc || Data:  (3, 1, 1, 2, 1, 0) || Actual:  unacc
# Predicted:  unacc || Data:  (1, 3, 1, 1, 0, 2) || Actual:  unacc
# Predicted:  good || Data:  (2, 2, 2, 0, 1, 0) || Actual:  good
# Predicted:  unacc || Data:  (0, 2, 3, 1, 0, 0) || Actual:  unacc
# Predicted:  good || Data:  (0, 3, 3, 2, 1, 0) || Actual:  good
# Predicted:  good || Data:  (0, 2, 0, 2, 2, 0) || Actual:  good
# Predicted:  good || Data:  (0, 0, 1, 0, 0, 2) || Actual:  good
# Predicted:  good || Data:  (2, 2, 2, 0, 0, 1) || Actual:  good
